# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r'D:\ITI\FinalProject\data\final.xlsx')
df.head()
# Out:
#                           Individual_ID                             Family_ID  \
# 0  31AE82A8-95D7-4E66-876D-8031121996A2  9A9D8DC8-9355-4128-9164-D260852720BF
# 1  FCDE46DA-77B1-499D-A3A2-84B87E19E85E  CB34CB01-2F0E-4C0D-A11D-E6357E8727AF
# 2  189336B9-6857-49C6-836D-C54AC6C2BEE9  068B1966-C39F-4BF2-92DE-1D52C947025D
# 3  1512A995-F9F6-4369-A967-6806B446B1F2  97358DDF-DF60-4406-8C95-0C62B0CF6E01
# 4  B6AC1F0E-C2AD-458C-BA2A-7A4026C03027  52CDDE65-7225-4717-BB8A-D1F713ADD602
#
#    GOV_CODE Governorate_Name Gender  AGE_CODE  Age  Marital_Status_Code  \
# 0         4           السويس    ذكر       NaN   38                  3.0
# 1        18          البحيرة   أنثى       1.0   37                  3.0
# 2        21           الجيزة    ذكر       1.0   28                  1.0
# 3        15        كفر الشيخ    ذكر       2.0    9                  NaN
# 4        17         المنوفية   أنثى       2.0   80                  5.0
#
#   Marital_Status Region_Type  ...  Work_Location_Type  \
# ...

# %%
df['Labor_Force_Status'].value_counts()
# Out:
# Labor_Force_Status
# خارج قوة العمل                   214550
# داخل قوة العمل (يعمل أو يبحث)     77543
# 4                                  3605
# 3                                  1026
# Name: count, dtype: int64

# %%
df['Salary_Level_Classification'].value_counts()
# Out:
# Salary_Level_Classification
# منخفض    35042
# متوسط    23066
# مرتفع    16618
# 4          708
# Name: count, dtype: int64

# %%
df[['Basic_Salary', 'Salary_Level_Classification']]
# Out:
#         Basic_Salary Salary_Level_Classification
# 0               3500                       متوسط
# 1                  0                         NaN
# 2                  0                         NaN
# 3                  0                         NaN
# 4                  0                         NaN
# ...              ...                         ...
# 296719             0                         NaN
# 296720             0                         NaN
# 296721             0                         NaN
# 296722           300                       منخفض
# 296723           300                       منخفض
#
# [296724 rows x 2 columns]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\ITI\FinalProject\data\member_info_2024_last.csv")
df.head()
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_16108\720595194.py:1: DtypeWarning: Columns (0: MEMBER_CODE, 1: EDU_LEAVE_REASON_OTHER, 2: PLACE_COURSE_OTHER, 3: COURSE_SUBJECT_OTHER, 4: REASON_TRAINING_OTHER, 5: PREV_CHANGE_REASON_OTHER, 6: WORK_PREVENT_REASON_OTHER, 7: SECTOR_OTHER_1, 8: TEXT_229_I_H, 9: WORK_SECOND_TARMEZ, 10: PLACE_OTHER, 11: SEARCH_WORK_FIRST_OTHER, 12: SEARCH_WORK_SECOND_OTHER, 13: MAIN_REASON_NO_SEARCH_OTHER, 14: SECTOR_OTHER, 15: REASON_STOP_WORK_OTHER, 16: UNPAID_WORK_TYPE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\ITI\FinalProject\data\member_info_2024_last.csv")
#                              RESPONSEID                      PARENTRESPONSEID  \
# 0  31AE82A8-95D7-4E66-876D-8031121996A2  9A9D8DC8-9355-4128-9164-D260852720BF
# 1  FCDE46DA-77B1-499D-A3A2-84B87E19E85E  CB34CB01-2F0E-4C0D-A11D-E6357E8727AF
# 2  189336B9-6857-49C6-836D-C54AC6C2BEE9  068B1966-C39F-4BF2-92DE-1D52C947025D
# ...

# %%
df.isna().sum() / len(df) * 100 > 75
# Out:
# RESPONSEID          False
# PARENTRESPONSEID    False
# DOMAINID            False
# PHASEID             False
# CREATIONPHASEID     False
#                     ...
# EMP_CODE_4           True
# ORIGINAL            False
# NORMAL              False
# QUARTER             False
# ORIGINAL_QUARTER    False
# Length: 235, dtype: bool

# %%
columns_to_drop = [
    'NAME_PERSON_FAMILY',
    'NOTCHIL_REGISTERED_CD',
    'NOT_PERSON_FAMILY_CODE',
    'EDU_LEAVE_REASON_OTHER',
    'GRADE1',
    'MARITAL_CONFIRM_FEMALE',
    'PLACE_COURSE_OTHER',
    'COURSE_SUBJECT_OTHER',
    'TRAINING_PERIOD_LESSMONTH',
    'TIME_RECYCLE',
    'REASON_TRAINING_OTHER',
    'UNDERSTANDING_CODE',
    'CHANGE_STAY_CODE',
    'OUT_IN_CODE',
    'PREV_PLACE_CODE',
    'PREV_PLACE_OUT',
    'PREV_CHANGE_YEAR',
    'PREV_CHANGE_REASON_CODE',
    'PREV_CHANGE_REASON_OTHER',
    'LAST_SMOKING_CODE',
    'LAST_DAY_SMOKING_CODE',
    'EDU_TRMEZ_REVIEW_CODE',
    'NOTICE',
    'NOT_ANSWER_HIMSELF',
    'PAID_WORK_TYPE_CODE',
    'WORK_PREVENT_REASON',
    'WORK_PREVENT_REASON_OTHER',
    'ABSENT_DURATION',
    'Q_204_A',
    'DECISIOMAKER',
    'HIRE_AWORKER_3MONTH',
    'ENTITYPROVIDE',
    'REGISTEREDOFFICIALRECORDS',
    'MANAGEPROJECT',
    'EST_NAME',
    'WORK_TYPE_CODE',
    'URCODE',
    'SECTOR_OTHER_1',
    'YEAR_NO',
    'VACATIONS_ILLNESS_CODE',
    'INDEMNITY_CODE',
    'CONTRACT_PERIOD_CODE',
    'FIXEDWAGE',
    'PAYWORKCOMPLETED',
    'COMMISSIONS',
    'TIPPING_GRATUITY',
    'FEES_EACHSERVICE',
    'NON_FINANCIALCONSIDERATION',
    'OTHER_229_H',
    'TEXT_229_I_H',
    'DONTGETPAID',
    'EST_ACCOUNTING_CODE',
    'EST_INDS_REG_COMM_CODE',
    'EST_INSURANCE_CODE',
    'WORK_ORG_FAM_CODE',
    'WORK_SECOND_TARMEZ',
    'TOT_EMP_CODE',
    'EST_ACCOUN_SECOND_CODE',
    'EST_INDS_REG_COM_SCND_CD',
    'EST_INSURANCE_SCND_CODE',
    'WRK_ORG_FAM_SCND_CODE',
    'PLACE_OTHER',
    'EXCH_PERIOD_SCND_CD',
    'ADD_HOUR_NO',
    'HOUR_SECOND_NO',
    'ADD_HOUR_CODE',
    'SRCH_PS_WK4_WRK_ADD_CD',
    'SEARCH_WEEK4_WORK_CODE',
    'COMMENT1',
    'START_WORK_CODE',
    'NO_DESIRE_OTHER',
    'SEARCH_WORK_WITHOUT_LIMT',
    'SEARCH_WORK_CODE',
    'SEARCH_WORK_FIRST_CODE',
    'SEARCH_WORK_FIRST',
    'SEARCH_WORK_FIRST_OTHER',
    'SEARCH_WORK_SECOND_CODE',
    'SEARCH_WORK_SECOND',
    'SEARCH_WORK_SECOND_OTHER',
    'SEARCH_WORK_THIRD_CODE',
    'SEARCH_WORK_THIRD',
    'SEARCH_WORK_THIRD_OTHER',
    'WORK_CODE',
    'MAIN_REASON_NO_SEARCH_OTHER',
    'GIVER_CODE_C',
    'EVER_WORK_CODE_1',
    'COMMENT_WRITE',
    'LAST_WORK',
    'LAST_ACT',
    'SECTOR_OTHER',
    'WORK_PLACE_CODE_CORONA',
    'REASON_STOP_WORK_CODE',
    'REASON_STOP_WORK_OTHER',
    'STOP_WORK_COUSECORONA',
    'STOP_WORK_MONTH',
    'REFUSED_JOP',
    'REFUSED_JOP_REASON_CODE',
    'REFUSED_JOP_REASON_OTHER',
    'PROBLEM_WORK_CODE',
    'PROBLEM_WORK_OTHER',
    'JOBTRZ_REV_CD_LST_WRK',
    'JOB_TRMEZ_CODE_LAST_WORK',
    'LST_ACT_TRZ_REV_CD',
    'LAST_ACT_TRMEZ_CODE',
    'GIVER_DESCRIPTION_CODE',
    'PRACTICE_UNPAID_ACT_CODE',
    'UNPAID_ACT_CODE',
    'WORK_ENTITY_CODE',
    'UNPAID_WORK_TYPE',
    'MJORUNPAIDOCCUPATIONREV',
    'MAINOCCUPUNPAIDINDVUA',
    'UNPAID_HOUR_NO',
    'ACT_SECOND_TARMEZ',
    'ORIGINAL',
    'NORMAL',
    'QUARTER',
    'ORIGINAL_QUARTER',
]

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296724 entries, 0 to 296723
# Columns: 118 entries, RESPONSEID to EMP_CODE_4
# dtypes: float64(97), int64(9), object(1), str(11)
# memory usage: 267.1+ MB

# %%
df.drop(columns = [col for col in df.columns if 'HOUSE_CONSUME_' in col], inplace=True)

# %%
df.drop(columns = [col for col in df.columns if 'EMP_CODE' in col], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296724 entries, 0 to 296723
# Columns: 104 entries, RESPONSEID to HOUR_CONSUME_9_NO
# dtypes: float64(83), int64(9), object(1), str(11)
# memory usage: 235.4+ MB

# %%
df.isna().sum() / len(df) * 100
# Out:
# RESPONSEID            0.000000
# PARENTRESPONSEID      0.000000
# DOMAINID              0.000000
# PHASEID               0.000000
# CREATIONPHASEID       0.000000
#                        ...
# HOUR_CONSUME_5_NO    92.669956
# HOUR_CONSUME_6_NO    99.540988
# HOUR_CONSUME_7_NO    99.972702
# HOUR_CONSUME_8_NO    99.845985
# HOUR_CONSUME_9_NO    99.985508
# Length: 104, dtype: float64

# %%
df.drop(
    columns = [col for col in df.columns if 'MARKET_CONSUM' in col],
    inplace = True
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296724 entries, 0 to 296723
# Data columns (total 93 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RESPONSEID                  296724 non-null  str
#  1   PARENTRESPONSEID            296724 non-null  str
#  2   DOMAINID                    296724 non-null  str
#  3   PHASEID                     296724 non-null  str
#  4   CREATIONPHASEID             296724 non-null  str
#  5   GOV_CODE                    296724 non-null  int64
#  6   STATION_CODE                296724 non-null  int64
#  7   SECTION_CODE                296724 non-null  int64
#  8   UR_CODE                     296724 non-null  float64
#  9   MEMBER_CODE                 296724 non-null  object
#  10  GIVER_NAME                  296724 non-null  int64
#  11  RELATION_CODE               296724 non-null  int64
#  12  GENDER_CODE                 296724 non-null  int64
# ...

# %%
df.drop(
    columns = [col for col in df.columns if 'HOUR_CONSUME' in col],
    inplace = True
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296724 entries, 0 to 296723
# Data columns (total 84 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RESPONSEID                  296724 non-null  str
#  1   PARENTRESPONSEID            296724 non-null  str
#  2   DOMAINID                    296724 non-null  str
#  3   PHASEID                     296724 non-null  str
#  4   CREATIONPHASEID             296724 non-null  str
#  5   GOV_CODE                    296724 non-null  int64
#  6   STATION_CODE                296724 non-null  int64
#  7   SECTION_CODE                296724 non-null  int64
#  8   UR_CODE                     296724 non-null  float64
#  9   MEMBER_CODE                 296724 non-null  object
#  10  GIVER_NAME                  296724 non-null  int64
#  11  RELATION_CODE               296724 non-null  int64
#  12  GENDER_CODE                 296724 non-null  int64
# ...

# %%
df.isna().sum() / len(df) * 100
# Out:
# RESPONSEID                     0.000000
# PARENTRESPONSEID               0.000000
# DOMAINID                       0.000000
# PHASEID                        0.000000
# CREATIONPHASEID                0.000000
#                                 ...
# AGE_CODE                      38.670279
# DESIRE_WORK_CODE              64.624702
# NO_DESIRE_CODE                41.934929
# MAIN_REASON_NO_SEARCH_CODE    98.561289
# SECTOR_CODE                   99.253178
# Length: 84, dtype: float64

# %%
columns_to_remove = [
    'EXCHANGE_PERIOD_CODE',
    'MEMBER_CODE',
    'GIVER_NAME',
    'CURRENT_YEAR',
    'BIRTH_MONTH',
    'GRADE',
    'QUALIFICATION_CODE',
    'STUDY_YEAR_NO',
    'UNEDUCATED_CODE',
]

# %%
df.drop(columns=columns_to_remove, inplace=True)

# %%
df['EDUCATION_CODE'].value_counts()
# Out:
# EDUCATION_CODE
# دبلوم تجارة                 9715
# دبلوم صنايع                 8182
# دبلوم تجاره                 6305
# دبلوم صناعى                 5111
# دبلوم صناعي                 4680
#                             ...
# يكالوريوس حاسب الى             1
# معهد سيارحه وفنادق             1
# بكالوريوس معهد تكنولوجيا       1
# معهد فنى تجار                  1
# بكالوريوس تربوى                1
# Name: count, Length: 4477, dtype: int64

# %%
df.shape
# Out:
# (296724, 75)

# %%
missing = df.isna().sum() / len(df) * 100
missing[missing > 0]
# Out:
# BIRTH_YEAR                      0.000674
# EDUCATION_JOIN_CODE            11.972068
# EDU_LEAVE_REASON_CODE          73.552190
# STAGE_CODE                     56.256656
# STAGE_CODE1                   100.000000
#                                  ...
# AGE_CODE                       38.670279
# DESIRE_WORK_CODE               64.624702
# NO_DESIRE_CODE                 41.934929
# MAIN_REASON_NO_SEARCH_CODE     98.561289
# SECTOR_CODE                    99.253178
# Length: 62, dtype: float64

# %%
eq = 0
for i in range(len(df)):
    if df.loc[i, 'REAL_AGE'] == df['REAL_AGE'].iloc[i]:
        eq += 1
print(f"Total matching rows: {eq}")
# Out:
# Total matching rows: 296724

# %%
df[df['REAL_AGE'] < 0]
# Out:
#                                   RESPONSEID  \
# 87      43554497-0460-418B-BD5F-23C1DE058411
# 191     CF520FC3-E503-4D20-BDF4-191F21EACEDF
# 456     2C04D274-BA19-4021-B3D4-2D903DA86418
# 498     2030E6DA-C17E-44D0-BBF1-C4A978BDD441
# 2297    0F7B30D4-6860-45BF-BED7-28EE0332C21A
# ...                                      ...
# 296119  423FEBF3-4EDD-46B6-B39B-24F7F849F529
# 296327  A80214E3-5C3E-48AD-8A24-731F22294789
# 296350  4E35C650-94F6-45E6-AC7D-2A048AD7E669
# 296460  275E7455-01B2-48C0-A7A9-DFD8800F5844
# 296508  69004EF2-FF5A-4730-92D3-95906D9456E7
#
#                             PARENTRESPONSEID  \
# 87      B772F33A-18C5-4342-8C84-504371C22C81
# 191     967ADBC0-91BA-4D4C-B5E9-B9F372C19DC0
# 456     E1904D57-884F-43F8-A839-87638658FB77
# 498     7E72D7DE-7E23-4BCC-BBE8-89C236EAF119
# 2297    B981F72E-D703-4C2F-B185-A9852BDC4648
# ...                                      ...
# 296119  C3C8B0AF-F110-4767-AF3F-102802734FBD
# 296327  40E97013-0C01-4DB6-BE9D-CFF167A784D4
# ...

# %%
df.drop(columns = 'REAL_AGE', inplace = True)

# %%
df.drop(columns='AGE_CODE', inplace=True)

# %%
df.shape
# Out:
# (296724, 73)

# %%
df['EDUCATION_JOIN_CODE'] = df.loc[df['EDUCATION_JOIN_CODE'].isna() & (df['AGE'] < 20), 'EDUCATION_JOIN_CODE'] = 1

# %%
df.to_csv(r"D:\ITI\FinalProject\data\my_cleansed_df.csv")

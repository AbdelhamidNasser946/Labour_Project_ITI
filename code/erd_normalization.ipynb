# %%
import numpy as np
import pandas as pd
import pyspark as ps

# %%
data = pd.read_excel(r'D:\ITI\FinalProject\data\final.xlsx')
data.shape
# Out:
# (296724, 73)

# %%
final_sample = data.sample(n = 10000)  # Sample 10% of data
final_sample.to_csv(r'D:\ITI\FinalProject\data\final_sample.csv', index=False)

# %%
final_sample.shape
# Out:
# (10000, 73)

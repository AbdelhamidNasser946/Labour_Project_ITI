# %%
import numpy as np
import pandas as pd
import openpyxl as op

# %%
new = pd.read_excel(r'D:\ITI\FinalProject\data\البيانات النهائية النسخه معدله.xlsx')
old = pd.read_excel(r'D:\ITI\FinalProject\data\final_cleaned_data.xlsx')

# %%
new.head()
# Out:
#                              INDIVIDUAL                            Unnamed: 1  \
# 0                            RESPONSEID                      PARENTRESPONSEID
# 1  31AE82A8-95D7-4E66-876D-8031121996A2  9A9D8DC8-9355-4128-9164-D260852720BF
# 2  FCDE46DA-77B1-499D-A3A2-84B87E19E85E  CB34CB01-2F0E-4C0D-A11D-E6357E8727AF
# 3  189336B9-6857-49C6-836D-C54AC6C2BEE9  068B1966-C39F-4BF2-92DE-1D52C947025D
# 4  1512A995-F9F6-4369-A967-6806B446B1F2  97358DDF-DF60-4406-8C95-0C62B0CF6E01
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6   Unnamed: 7  \
# 0        GOV     GENDER        AGE     MARITAL         UR     RELATION
# 1     السويس        ذكر         38     متزوج/ة        حضر  رئيس الأسرة
# 2    البحيرة       أنثى         37     متزوج/ة        ريف     زوج/زوجة
# 3     الجيزة        ذكر         28  أعزب/عزباء        حضر     ابن/ابنة
# 4  كفر الشيخ        ذكر          9         NaN        حضر     ابن/ابنة
#
# ...

# %%
new.columns = new.iloc[0]
new = new[1:].reset_index(drop=True)

# %%
new.head()
# Out:
# 0                            RESPONSEID                      PARENTRESPONSEID  \
# 0  31AE82A8-95D7-4E66-876D-8031121996A2  9A9D8DC8-9355-4128-9164-D260852720BF
# 1  FCDE46DA-77B1-499D-A3A2-84B87E19E85E  CB34CB01-2F0E-4C0D-A11D-E6357E8727AF
# 2  189336B9-6857-49C6-836D-C54AC6C2BEE9  068B1966-C39F-4BF2-92DE-1D52C947025D
# 3  1512A995-F9F6-4369-A967-6806B446B1F2  97358DDF-DF60-4406-8C95-0C62B0CF6E01
# 4  B6AC1F0E-C2AD-458C-BA2A-7A4026C03027  52CDDE65-7225-4717-BB8A-D1F713ADD602
#
# 0        GOV GENDER AGE     MARITAL   UR     RELATION          EDU  \
# 0     السويس    ذكر  38     متزوج/ة  حضر  رئيس الأسرة    ثانوي فني
# 1    البحيرة   أنثى  37     متزوج/ة  ريف     زوج/زوجة   يقرأ ويكتب
# 2     الجيزة    ذكر  28  أعزب/عزباء  حضر     ابن/ابنة    ثانوي فني
# 3  كفر الشيخ    ذكر   9         NaN  حضر     ابن/ابنة  أقل من السن
# 4   المنوفية   أنثى  80      أرمل/ة  ريف        أب/أم          أمي
#
# 0     EDUCATION_JOIN  ...         CONTRACT_PERIOD    WORK_PLACE  \
# ...

# %%
old.head()
# Out:
#                             response_id  GOV_CODE governorate_code  \
# 0  31AE82A8-95D7-4E66-876D-8031121996A2         4           السويس
# 1  FCDE46DA-77B1-499D-A3A2-84B87E19E85E        18          البحيرة
# 2  189336B9-6857-49C6-836D-C54AC6C2BEE9        21           الجيزة
# 3  1512A995-F9F6-4369-A967-6806B446B1F2        15        كفر الشيخ
# 4  B6AC1F0E-C2AD-458C-BA2A-7A4026C03027        17         المنوفية
#
#    survey_station_code  section_code urban_rural_code member_id  \
# 0                  404         40401              حضر         1
# 1                 1809        180918              ريف         2
# 2                 2105        210503              حضر         5
# 3                 1502        150201              حضر         4
# 4                 1705        170522              ريف         3
#
#   relationship_to_head_code gender_code  birth_month  ...  \
# 0               رئيس الأسرة         ذكر          4.0  ...
# ...

# %%
new['SALARY'] = old['calculated_salary']

# %%
new['SALARY'].head(10)
# Out:
# 0    3500
# 1       0
# 2       0
# 3       0
# 4       0
# 5    3000
# 6       0
# 7       0
# 8       0
# 9       0
# Name: SALARY, dtype: int64

# %%
new.shape
# Out:
# (296724, 70)

# %%
old.shape
# Out:
# (296724, 68)

# %%
new
# Out:
# 0                                 RESPONSEID  \
# 0       31AE82A8-95D7-4E66-876D-8031121996A2
# 1       FCDE46DA-77B1-499D-A3A2-84B87E19E85E
# 2       189336B9-6857-49C6-836D-C54AC6C2BEE9
# 3       1512A995-F9F6-4369-A967-6806B446B1F2
# 4       B6AC1F0E-C2AD-458C-BA2A-7A4026C03027
# ...                                      ...
# 296719  EC9B3617-2A83-4BF5-AC76-12BA0C8F488D
# 296720  05AE321C-908A-48B9-B785-4ED4C0A6DE8F
# 296721  411B88A4-C384-4B03-BCCF-4EEC8AB08495
# 296722  665DAA91-B90A-4A81-A612-4F4FC284BA34
# 296723  FC5696A6-6A8E-4AB2-A49B-02FFC449ABBD
#
# 0                           PARENTRESPONSEID        GOV GENDER AGE  \
# 0       9A9D8DC8-9355-4128-9164-D260852720BF     السويس    ذكر  38
# 1       CB34CB01-2F0E-4C0D-A11D-E6357E8727AF    البحيرة   أنثى  37
# 2       068B1966-C39F-4BF2-92DE-1D52C947025D     الجيزة    ذكر  28
# 3       97358DDF-DF60-4406-8C95-0C62B0CF6E01  كفر الشيخ    ذكر   9
# 4       52CDDE65-7225-4717-BB8A-D1F713ADD602   المنوفية   أنثى  80
# ...

# %%
new['AGE'].value_counts()
# Out:
# AGE
# 5      8014
# 10     7515
# 9      7380
# 11     7217
# 12     7107
#        ...
# 101       4
# 96        3
# 98        3
# 99        3
# 97        1
# Name: count, Length: 102, dtype: int64

# %%
new[new['AGE'] < 5]
# Out:
# 0                                 RESPONSEID  \
# 23      0302C167-FA0C-45C8-AA96-0FA968FB9B0E
# 36      1F8D4DD1-11FA-4706-B29A-6D13033FD760
# 39      663DB94F-5551-4AAB-819A-F4A48BE6DF7A
# 43      62B790B3-421E-4DBA-9D73-9376429797CF
# 45      87372FEC-82D2-4B1C-AF76-E54E15C6BC96
# ...                                      ...
# 296649  FEF901BB-B564-4658-9D86-FA9BDEDDABB5
# 296661  E0BE18E2-10EF-4929-A9FE-078E7B6EDFE1
# 296687  13A242BA-0F8A-41B0-A203-9D3B52C105E9
# 296710  C671365C-C425-4CFE-BECE-1CE28423C012
# 296713  2E97FD43-EB32-4BDB-8933-1273326C12EE
#
# 0                           PARENTRESPONSEID         GOV GENDER AGE MARITAL  \
# 23      DD5B37B9-85B6-45C9-BBD8-E006BB1A1D1A       أسيوط   أنثى   1     NaN
# 36      A9CD06A7-2D4A-4FB1-9E2F-79393FCE2285    بني سويف    ذكر   0     NaN
# 39      22B0EF33-63DF-4973-B8F2-2D07F0C20938    الدقهلية    ذكر   2     NaN
# 43      E8843C25-3812-4DFF-9542-DC77916B187C  جنوب سيناء    ذكر   3     NaN
# ...
